# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv('/content/vgsales.csv')

# %%
df.head(15)
# Out:
#     Rank                         Name Platform    Year         Genre  \
# 0      1                   Wii Sports      Wii  2006.0        Sports
# 1      2            Super Mario Bros.      NES  1985.0      Platform
# 2      3               Mario Kart Wii      Wii  2008.0        Racing
# 3      4            Wii Sports Resort      Wii  2009.0        Sports
# 4      5     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 5      6                       Tetris       GB  1989.0        Puzzle
# 6      7        New Super Mario Bros.       DS  2006.0      Platform
# 7      8                     Wii Play      Wii  2006.0          Misc
# 8      9    New Super Mario Bros. Wii      Wii  2009.0      Platform
# 9     10                    Duck Hunt      NES  1984.0       Shooter
# 10    11                   Nintendogs       DS  2005.0    Simulation
# 11    12                Mario Kart DS       DS  2005.0        Racing
# 12    13  Pokemon Gold/Pokemon Silver       GB  1999.0  Role-Playing
# ...

# %%
df = df.drop_duplicates()
df #no duplicates
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df =df.drop(['Rank'],axis=1)

# %%
df.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16327.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    2006.406443      0.264667      0.146652      0.077782      0.048063
# std        5.828981      0.816683      0.505351      0.309291      0.188588
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global_Sales
# count  16598.000000
# mean       0.537441
# std        1.555028
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.470000
# max       82.740000

# %%
df.describe(include='O')
# Out:
#                                Name Platform   Genre        Publisher
# count                         16598    16598   16598            16540
# unique                        11493       31      12              578
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2163    3316             1351

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Name            0.000000
# Platform        0.000000
# Year            1.632727
# Genre           0.000000
# Publisher       0.349440
# NA_Sales        0.000000
# EU_Sales        0.000000
# JP_Sales        0.000000
# Other_Sales     0.000000
# Global_Sales    0.000000
# dtype: float64

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16291 non-null  object
#  1   Platform      16291 non-null  object
#  2   Year          16291 non-null  float64
#  3   Genre         16291 non-null  object
#  4   Publisher     16291 non-null  object
#  5   NA_Sales      16291 non-null  float64
#  6   EU_Sales      16291 non-null  float64
#  7   JP_Sales      16291 non-null  float64
#  8   Other_Sales   16291 non-null  float64
#  9   Global_Sales  16291 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.4+ MB

# %%
# Publisher

# %%
df.Publisher.value_counts()
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
#                                 ...
# Detn8 Games                        1
# Pow                                1
# Navarre Corp                       1
# MediaQuest                         1
# UIG Entertainment                  1
# Name: Publisher, Length: 576, dtype: int64

# %%
df['Publisher'] = df['Publisher'].str.strip()

count =df.Publisher.value_counts()
count[count>100].sum()/16291
# labeling any thing greater than 100 as they represent 72% of the total
# Out:
# <ipython-input-15-c25ddf5a63f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Publisher'] = df['Publisher'].str.strip()
# 0.7205819163955558

# %%
sns.barplot(y=count[count>100].index, x=count[count>100].values)
# Out:
# <Axes: ylabel='None'>

# %%
pub = count[count > 100]

# Replace publishers that are not in the 'pub' list with 'Other'
df['Publisher'] = np.where(df['Publisher'].isin(pub.index), df['Publisher'], 'Other')

# Check the value counts after replacement
df['Publisher'].value_counts()
# Out:
# Other                                     4552
# Electronic Arts                           1339
# Activision                                 966
# Namco Bandai Games                         928
# Ubisoft                                    918
# Konami Digital Entertainment               823
# THQ                                        712
# Nintendo                                   696
# Sony Computer Entertainment                682
# Sega                                       632
# Take-Two Interactive                       412
# Capcom                                     376
# Atari                                      347
# Tecmo Koei                                 338
# Square Enix                                231
# Warner Bros. Interactive Entertainment     217
# Disney Interactive Studios                 214
# Eidos Interactive                          196
# Midway Games                               196
# 505 Games                                  192
# ...

# %% [markdown]
# Genre

# %%
df.Genre.value_counts()
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
df['Genre'].value_counts().plot.pie(autopct = "%1.1f%%")
plt.title('Genre')
# Out:
# Text(0.5, 1.0, 'Genre')

# %% [markdown]
# Year

# %%
df.Year.describe()
# Out:
# count    16291.000000
# mean      2006.405561
# std          5.832412
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year, dtype: float64

# %%
year = df['Year'].value_counts().sort_index()

fig, axs = plt.subplots()
axs.fill_between(year.index, year.values, color='#ADDDD0', alpha=0.5, label='Years')
axs.set_xlabel('Years')
axs.set_ylabel('Frequency')
axs.set_title('years sale')
axs.legend()
plt.show()

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# Platform

# %%
plat_count = df.Platform.value_counts()
plat_count[plat_count>200].sum()/plat_count.sum()*100
# replacing any thing below count of 200 with others as the rest represents 95% of data
# Out:
# 95.47602970965563

# %%
plat_count = df['Platform'].value_counts()

# Replace publishers that are not in the 'pub' list with 'Other'
selected_platforms = plat_count[plat_count > 200]
df['Platform'] = np.where(df['Platform'].isin(selected_platforms.index), df['Platform'], 'Other')
# Check the value counts after replacement
df['Platform'].value_counts()
# Out:
# DS       2131
# PS2      2127
# PS3      1304
# Wii      1290
# X360     1234
# PSP      1197
# PS       1189
# PC        938
# XB        803
# GBA       786
# Other     737
# GC        542
# 3DS       499
# PSV       410
# PS4       336
# N64       316
# SNES      239
# XOne      213
# Name: Platform, dtype: int64

# %%
sns.countplot(x=df.Platform)
plt.xticks(rotation=45)
plt.title("Platform count")
# Out:
# Text(0.5, 1.0, 'Platform count')

# %% [markdown]
# Name

# %%
game=df.Name.value_counts()
popular=game[:30]
popular
# Out:
# Need for Speed: Most Wanted                      12
# FIFA 14                                           9
# Ratatouille                                       9
# LEGO Marvel Super Heroes                          9
# Cars                                              8
# LEGO The Hobbit                                   8
# Monopoly                                          8
# FIFA Soccer 13                                    8
# Madden NFL 08                                     8
# Angry Birds Star Wars                             8
# Terraria                                          8
# FIFA 15                                           8
# LEGO Jurassic World                               8
# Madden NFL 07                                     8
# The LEGO Movie Videogame                          8
# LEGO Star Wars II: The Original Trilogy           8
# Lego Batman 3: Beyond Gotham                      8
# LEGO The Lord of the Rings                        7
# ...

# %%
df['Name'] = np.where(df['Name'].isin(popular.index), df['Name'], 'Other')
# Check the value counts after replacement
df['Name'].value_counts()
# Out:
# Other                                            16057
# Need for Speed: Most Wanted                         12
# FIFA 14                                              9
# Ratatouille                                          9
# LEGO Marvel Super Heroes                             9
# FIFA Soccer 13                                       8
# Angry Birds Star Wars                                8
# LEGO The Hobbit                                      8
# Terraria                                             8
# Lego Batman 3: Beyond Gotham                         8
# LEGO Jurassic World                                  8
# Cars                                                 8
# The LEGO Movie Videogame                             8
# FIFA 15                                              8
# Monopoly                                             8
# Madden NFL 08                                        8
# Madden NFL 07                                        8
# ...

# %%
df
# Out:
#         Name Platform    Year         Genre   Publisher  NA_Sales  EU_Sales  \
# 0      Other      Wii  2006.0        Sports    Nintendo     41.49     29.02
# 1      Other    Other  1985.0      Platform    Nintendo     29.08      3.58
# 2      Other      Wii  2008.0        Racing    Nintendo     15.85     12.88
# 3      Other      Wii  2009.0        Sports    Nintendo     15.75     11.01
# 4      Other    Other  1996.0  Role-Playing    Nintendo     11.27      8.89
# ...      ...      ...     ...           ...         ...       ...       ...
# 16593  Other      GBA  2002.0      Platform       Other      0.01      0.00
# 16594  Other       GC  2003.0       Shooter       Other      0.01      0.00
# 16595  Other      PS2  2008.0        Racing  Activision      0.00      0.00
# 16596  Other       DS  2010.0        Puzzle       Other      0.00      0.01
# 16597  Other      GBA  2003.0      Platform       Other      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
sns.barplot(x=popular.index, y=popular.values)
plt.xticks(rotation=90)
plt.title("Most popular games")
# Out:
# Text(0.5, 1.0, 'Most popular games')

# %% [markdown]
# EDA sales

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
sns.lineplot(x =df["Year"], y = df["NA_Sales"], color='gold')
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
sns.lineplot(x =df["Year"], y = df["EU_Sales"], color='blue')
# Out:
# <Axes: xlabel='Year', ylabel='EU_Sales'>

# %%
sns.lineplot(x =df["Year"], y = df["JP_Sales"], color='red')
# Out:
# <Axes: xlabel='Year', ylabel='JP_Sales'>

# %%
sns.lineplot(x =df["Year"], y = df["Other_Sales"], color='teal')
# Out:
# <Axes: xlabel='Year', ylabel='Other_Sales'>

# %%
sns.lineplot(x =df["Year"], y = df["Global_Sales"], color='black')
# Out:
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %% [markdown]
# Label encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16291 non-null  object
#  1   Platform      16291 non-null  object
#  2   Year          16291 non-null  float64
#  3   Genre         16291 non-null  object
#  4   Publisher     16291 non-null  object
#  5   NA_Sales      16291 non-null  float64
#  6   EU_Sales      16291 non-null  float64
#  7   JP_Sales      16291 non-null  float64
#  8   Other_Sales   16291 non-null  float64
#  9   Global_Sales  16291 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.4+ MB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cols = ['Name', 'Platform', 'Genre',
       'Publisher']
df[cols] = df[cols].apply(LabelEncoder().fit_transform)
df.head()
# Out:
#    Name  Platform    Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0    20        14  2006.0     10         16     41.49     29.02      3.77
# 1    20         5  1985.0      4         16     29.08      3.58      6.81
# 2    20        14  2008.0      6         16     15.85     12.88      3.79
# 3    20        14  2009.0     10         16     15.75     11.01      3.28
# 4    20         5  1996.0      7         16     11.27      8.89     10.22
#
#    Other_Sales  Global_Sales
# 0         8.46         82.74
# 1         0.77         40.24
# 2         3.31         35.82
# 3         2.96         33.00
# 4         1.00         31.37

# %% [markdown]
# Outliers

# %%
df.plot(kind = "box" , subplots = True , figsize = (20,20) , layout = (7,4))
# Out:
# Name               Axes(0.125,0.786098;0.168478x0.0939024)
# Platform        Axes(0.327174,0.786098;0.168478x0.0939024)
# Year            Axes(0.529348,0.786098;0.168478x0.0939024)
# Genre           Axes(0.731522,0.786098;0.168478x0.0939024)
# Publisher          Axes(0.125,0.673415;0.168478x0.0939024)
# NA_Sales        Axes(0.327174,0.673415;0.168478x0.0939024)
# EU_Sales        Axes(0.529348,0.673415;0.168478x0.0939024)
# JP_Sales        Axes(0.731522,0.673415;0.168478x0.0939024)
# Other_Sales        Axes(0.125,0.560732;0.168478x0.0939024)
# Global_Sales    Axes(0.327174,0.560732;0.168478x0.0939024)
# dtype: object

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Linear regression

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(['Global_Sales'], axis=1)
x=df.drop(['Global_Sales'], axis=1).values
y=df.Global_Sales.values
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=.25, random_state=45)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
reg =lr.fit(X_train, y_train)

# %%
lr.score(X_train, y_train)
# Out:
# 0.9999869161425315

# %%
lr.score(X_test, y_test)
# Out:
# 0.9999923566976997

# %%
reg.coef_
# Out:
# array([ 5.74352435e-05, -1.35979842e-05, -5.45334368e-07,  1.01077860e-05,
#        -2.10987375e-05,  9.99895409e-01,  1.00002760e+00,  9.99922014e-01,
#         9.99704508e-01])

# %%
pd.DataFrame(reg.coef_, df.columns[:-1] , columns = ["coeficient"])
# Out:
#                coeficient
# Name         5.743524e-05
# Platform    -1.359798e-05
# Year        -5.453344e-07
# Genre        1.010779e-05
# Publisher   -2.109874e-05
# NA_Sales     9.998954e-01
# EU_Sales     1.000028e+00
# JP_Sales     9.999220e-01
# Other_Sales  9.997045e-01

# %%
reg.intercept_
# Out:
# 0.0006134214687332218

# %%
y_pred = lr.predict(X_test)

# %%
data = pd.DataFrame({"Y_test" : y_test , "Y_predict": y_pred})
data.head(10)
# Out:
#    Y_test  Y_predict
# 0    0.38   0.380488
# 1    0.26   0.260657
# 2    1.27   1.259916
# 3    0.78   0.779969
# 4    0.09   0.090346
# 5    0.22   0.219953
# 6    0.18   0.179982
# 7    0.54   0.540247
# 8    0.50   0.500295
# 9    0.02   0.020190

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import r2_score

# %%
reg_score=r2_score(y_test,y_pred)
reg_score
# Out:
# 0.9999923566976997

# %%
p = X_train.shape[1]  # Get the number of columns (features) in X_train
n = len(y_train)
adj_R2 = 1 - (reg_score) * (n - 1) / (n - p - 1)
adj_R2
# Out:
# -0.0007295725569951284

# %%
from sklearn.metrics import mean_absolute_error , mean_absolute_percentage_error , mean_squared_error

# %%
mean_squared_error(y_test , y_pred)
# Out:
# 2.7429177279912244e-05

# %%
mean_absolute_percentage_error(y_test , y_pred)
# Out:
# 0.028254684067886372

# %%
data = pd.DataFrame({"Y_test" : y_test , "Y_predict": y_pred})
plt.figure(figsize= (12,6))
plt.plot(data[:10])
plt.legend(["Actual" , " Predicted"])

# %%
import statsmodels.api as sm

# %%
x2 = sm.add_constant(x)
est = sm.OLS(y , x2)
est2 = est.fit()
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.631e+08
# Date:                Mon, 22 Jan 2024   Prob (F-statistic):               0.00
# Time:                        07:44:44   Log-Likelihood:                 62496.
# No. Observations:               16291   AIC:                        -1.250e+05
# Df Residuals:                   16281   BIC:                        -1.249e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0033      0.015      0.222      0.824      -0.026       0.032
# ...

# %% [markdown]
# Model2

# %%
from sklearn import linear_model

# %%
ridge = linear_model.Ridge(alpha=.5)
rid=ridge.fit(X_train, y_train)

# %%
rid.coef_
# Out:
# array([ 5.28435245e-05, -1.48312922e-05, -4.53083298e-07,  1.12196969e-05,
#        -2.01521330e-05,  1.00009463e+00,  1.00017260e+00,  9.99444143e-01,
#         9.98091453e-01])

# %%
rid.intercept_
# Out:
# 0.0005513390480668123

# %%
rid.score(X_train, y_train)
# Out:
# 0.9999868818250536

# %%
rid.score(X_test, y_test)
# Out:
# 0.9999923544821749

# %%
pd.DataFrame(rid.coef_, df.columns[:-1] , columns = ["coeficient"])
# Out:
#                coeficient
# Name         5.284352e-05
# Platform    -1.483129e-05
# Year        -4.530833e-07
# Genre        1.121970e-05
# Publisher   -2.015213e-05
# NA_Sales     1.000095e+00
# EU_Sales     1.000173e+00
# JP_Sales     9.994441e-01
# Other_Sales  9.980915e-01

# %%
y_pred = ridge.predict(X_test)

# %%
data = pd.DataFrame({"Y_test" : y_test , "Y_predict": y_pred})
data.head(10)
# Out:
#    Y_test  Y_predict
# 0    0.38   0.380589
# 1    0.26   0.260741
# 2    1.27   1.259964
# 3    0.78   0.779063
# 4    0.09   0.090375
# 5    0.22   0.220001
# 6    0.18   0.180031
# 7    0.54   0.540266
# 8    0.50   0.500355
# 9    0.02   0.020211

# %% [markdown]
# Evaluation

# %%
rid_score=r2_score(y_test,y_pred)
rid_score
# Out:
# 0.9999923544821749

# %%
p = X_train.shape[1]  # Get the number of columns (features) in X_train
n = len(y_train)
adj_R2 = 1 - (rid_score) * (n - 1) / (n - p - 1)
adj_R2
# Out:
# -0.0007295703398371156

# %%
mean_squared_error(y_test , y_pred)
# Out:
# 2.7437128034695827e-05

# %%
mean_absolute_percentage_error(y_test , y_pred)
# Out:
# 0.028609791611072726

# %%
data = pd.DataFrame({"Y_test" : y_test , "Y_predict": y_pred})
plt.figure(figsize= (12,6))
plt.plot(data[:10])
plt.legend(["Actual" , " Predicted"])

# %%
from sklearn.linear_model import LassoLars

# %%
clf = linear_model.Lasso(alpha=0.1)

# %%
clf.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
clf.score(X_train,y_train)
# Out:
# 0.9358528473597719

# %%
clf.score(X_test,y_test)
# Out:
# 0.9610013181676681

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree
dtr=DecisionTreeRegressor(max_depth=3, random_state=2529)

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=2529)

# %%
dtr.score(X_train,y_train)
# Out:
# 0.8839067060180068

# %%
from sklearn.model_selection import cross_validate
cross_validate(dtr, X_train, y_train, cv=5)
# Out:
# {'fit_time': array([0.01745367, 0.01335406, 0.01256561, 0.01217532, 0.0122602 ]),
#  'score_time': array([0.00124955, 0.00114608, 0.00097466, 0.00103998, 0.00104761]),
#  'test_score': array([0.76196581, 0.86107346, 0.82971729, 0.85818072, 0.78984825])}

# %%
dtr.score(X_test,y_test)
# Out:
# 0.7615510797639853

# %%
params = {'model__max_depth' : [2,3,4,5,6,7,8, 9, 10],
        'model__criterion' : ['squared_error', 'absolute_error'],
        'model__random_state' : [2529]}

# %%
from sklearn.pipeline import Pipeline
pipe = Pipeline([('model', dtr)])

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(pipe,params,cv=5)

# %%
grid
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('model',
#                                         DecisionTreeRegressor(max_depth=3,
#                                                               random_state=2529))]),
#              param_grid={'model__criterion': ['squared_error',
#                                               'absolute_error'],
#                          'model__max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10],
#                          'model__random_state': [2529]})

# %%
dtr.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 2529,
#  'splitter': 'best'}

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('model',
#                                         DecisionTreeRegressor(max_depth=3,
#                                                               random_state=2529))]),
#              param_grid={'model__criterion': ['squared_error',
#                                               'absolute_error'],
#                          'model__max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10],
#                          'model__random_state': [2529]})

# %%
best = grid.best_estimator_
grid.best_params_
# Out:
# {'model__criterion': 'squared_error',
#  'model__max_depth': 10,
#  'model__random_state': 2529}

# %%
best.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('model',
#                  DecisionTreeRegressor(max_depth=10, random_state=2529))])

# %%
fig,ax = plt.subplots(figsize=(15,10))
final=DecisionTreeRegressor(max_depth=3, random_state=2529)
final.fit(X_train,y_train)
plot_tree(final,feature_names=df.columns,filled=True);

# %%
from sklearn.ensemble import RandomForestRegressor
r = RandomForestRegressor()
r.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=r.predict(X_test)
y_pred
# Out:
# array([0.3782, 0.2611, 1.2705, ..., 0.3409, 0.0204, 0.0536])

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.8391266642125769

# %%
fig,ax = plt.subplots(figsize=(15,10))
finall=RandomForestRegressor(n_estimators=3, max_depth = 3)
finall.fit(X_train,y_train)
plot_tree(final,feature_names=df.columns,filled=True);

# %%
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tree = r.estimators_[9]
# Export the image to a dot file
export_graphviz(tree, out_file = 'tr.dot', feature_names = X.columns, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tr.dot')
# Write graph to a png file
graph.write_png('tr.png')

# %%
# Limit depth of tree to 3 levels
rf_small = RandomForestRegressor(n_estimators=10, max_depth = 3)
rf_small.fit(X_train, y_train)
# Extract the small tree
tree_small = rf_small.estimators_[5]
# Save the tree as a png image
export_graphviz(tree_small, out_file = 'small_tree.dot', feature_names = X.columns, rounded = True, precision = 1)
(graph, ) = pydot.graph_from_dot_file('small_tree.dot')
graph.write_png('small_tree.png');

# %% [markdown]
# DecisionTreeRegressor

# %%
# import the regressor
from sklearn.tree import DecisionTreeRegressor

# create a regressor object
regressor1 = DecisionTreeRegressor(random_state = 0)

# fit the regressor with X and Y data
regressor1.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred1 = regressor1.predict(X_test)

# %%
mse1 = mean_squared_error(y_test, y_pred1)
mae2 = mean_absolute_error(y_test, y_pred1)

#Print the results
print('Decision Tree Regressorn:')
print('MSE:', mse1)
print('MAE:', mae2)
# Out:
# Decision Tree Regressorn:
# MSE: 0.5819561475298032
# MAE: 0.05381864309681645

# %%
regressor1.score(X_test, y_test)
# Out:
# 0.8378344813010217

# %%
# import export_graphviz
from sklearn.tree import export_graphviz

# export the decision tree to a tree.dot file
# for visualizing the plot easily anywhere
export_graphviz(regressor1, out_file ='tree.png')

# %%
! dot -Tpdf tree.dot -o tree.pdf
# Out:
# Error: dot: can't open tree.dot

# %%
! xdot tree.dot
# Out:
# /bin/bash: line 1: xdot: command not found

# %% [markdown]
# Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_pred = regressor.predict(X_test)

# %%
#Calculate the MSE and MAE
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
#Print the results
print('Random Forest Regression:')
print('MSE:', mse)
print('MAE:', mae)
# Out:
# Random Forest Regression:
# MSE: 0.6243538583203511
# MAE: 0.04403965516233501

# %%
regressor.score(X_test, y_test)
# Out:
# 0.8260201087040789

# %%
regressor2 = RandomForestRegressor(n_estimators = 50, random_state = 0,max_depth=10)
regressor2.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=50, random_state=0)

# %%
y_pred2 = regressor2.predict(X_test)

# %%
#Calculate the MSE and MAE
mse = mean_squared_error(y_test, y_pred2)
mae = mean_absolute_error(y_test, y_pred2)
#Print the results
print('Random Forest Regression:')
print('MSE:', mse)
print('MAE:', mae)
# Out:
# Random Forest Regression:
# MSE: 0.5670020196791894
# MAE: 0.049438030357852755

# %%
print(regressor2.score(X_train, y_train))
print(regressor2.score(X_test, y_test))
# Out:
# 0.9948398178953989
# 0.8420015373753995

# %%
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_pred = regressor.predict(X_test)

# %%
#Calculate the MSE and MAE
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
#Print the results
print('Random Forest Regression:')
print('MSE:', mse)
print('MAE:', mae)
# Out:
# Random Forest Regression:
# MSE: 0.6243538583203511
# MAE: 0.04403965516233501

# %%
df
# Out:
#        Name  Platform    Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0        20        14  2006.0     10         16     41.49     29.02      3.77
# 1        20         5  1985.0      4         16     29.08      3.58      6.81
# 2        20        14  2008.0      6         16     15.85     12.88      3.79
# 3        20        14  2009.0     10         16     15.75     11.01      3.28
# 4        20         5  1996.0      7         16     11.27      8.89     10.22
# ...     ...       ...     ...    ...        ...       ...       ...       ...
# 16593    20         2  2002.0      4         18      0.01      0.00      0.00
# 16594    20         3  2003.0      8         18      0.01      0.00      0.00
# 16595    20         8  2008.0      6          2      0.00      0.00      0.00
# 16596    20         1  2010.0      5         18      0.00      0.01      0.00
# 16597    20         2  2003.0      4         18      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# ...

# %%
name = input("what do like sport or pokemon?")
if name == 'sport':
    name = 1
else:
    name = 0

print(name)
# Out:
# what do like sport or pokemon?1
# 0

# %%
Platform = input("What is the platform wii or nes")
if Platform == 'wii':
    Platform = 18
else:
    Platform = 8
# Out:
# What is the platform wii or nes1

# %%
Genre = input("the genre is sport or Action?")
if Genre == 'Action':
    Genre = 11
else:
    Genre = 3
# Out:
# the genre is sport or Action?1

# %%
Year = float(input("what is the Year?"))
NA_Sales = 20.0
EU_Sales = 18.1
JP_Sales = 7.99
Other_Sales = 12.1
# Out:
# what is the Year?0

# %%
dtr.predict([[name,Platform,Genre,Publisher,Year,NA_Sales,EU_Sales,JP_Sales,Other_Sales]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e571752125f4> in <cell line: 1>()
# ----> 1 dtr.predict([[name,Platform,Genre,Publisher,Year,NA_Sales,EU_Sales,JP_Sales,Other_Sales]])
#
# NameError: name 'dtr' is not defined
